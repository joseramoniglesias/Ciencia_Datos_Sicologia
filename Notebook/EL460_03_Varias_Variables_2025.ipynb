# %% [markdown]
# # Varias Variables<a class="tocSkip">
# ## Inteligencia Artificial - Machine Learning<a class="tocSkip">
# ### Ingenieria Electrónica <a class="tocSkip">
# ### Universidad Popular del Cesar <a class="tocSkip">
# ### Prof.: Jose Ramón Iglesias Gamarra - [https://github.com/joseramoniglesias/](https://github.com/joseramoniglesias/) <a class="tocSkip">
#   **joseiglesias@unicesar.edu.co**
# ---
#
# # Varias Variables

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import seaborn

seaborn.set_context('talk')

# %% [markdown]
# ## Lectura del dataset
#
# En la notebook 00 se explican los detalles de la siguiente sección.

# %%
df = pd.read_csv('sysarmy_survey_2020_processed.csv')

# %%
df[:3]
# Out:
#   profile_gender  profile_age work_country                    work_province  \
# 0          Mujer           26    Argentina  Ciudad Autónoma de Buenos Aires
# 1         Hombre           29    Argentina                       Corrientes
# 2          Mujer           22    Argentina  Ciudad Autónoma de Buenos Aires
#
#    profile_years_experience  work_years_in_company  \
# 0                       3.0                    3.0
# 1                       5.0                    2.0
# 2                       2.0                    0.0
#
#    work_years_in_current_position  work_people_in_charge_of  \
# 0                             3.0                         0
# 1                             2.0                         4
# 2                             0.0                         0
#
#   profile_studies_level profile_studies_level_state  ...  \
# 0         Universitario                    En curso  ...
# 1         Universitario                    En curso  ...
# 2            Secundario                  Completado  ...
#
#   work_has_violence_situations profile_sexual_orientation  \
# 0         En mi trabajo actual                 Homosexual
# 1                        Jamás               Heterosexual
# 2       En un trabajo anterior           Bisexual o queer
#
#   profile_has_disabilities profile_has_disabilities_hiring_difficulties  \
# 0                      NaN                                          NaN
# 1                   Visual                                           No
# 2                      NaN                                           No
#
#   company_employee_number                          company_main_activity  \
# 0                501-1000  Servicios / Consultoría de Software / Digital
# 1                 201-500                               Otras industrias
# 2               2001-5000                               Otras industrias
#
#   company_recommended company_diversity_policies  \
# 0                   7                          2
# 1                   8                          9
# 2                   6                          9
#
#                               company_extra_benefits  \
# 0  Capacitaciones y/o cursos, Comidas pagas / sub...
# 1  Horarios flexibles, Stock options / RSUs, Viát...
# 2  Clases de gimnasia online, Comidas pagas / sub...
#
#   company_best_companies_city
# 0                         NaN
# 1                         NaN
# 2                         NaN
#
# [3 rows x 48 columns]

# %% [markdown]
# # Variables Categóricas

# %%
fig = plt.figure(figsize=(6,4)) #se genera la figura y se define su tamaño
#seaborn.countplot(df.profile_gender, color='steelblue') # gráfico de conteos de la primer columna (profile_gender)
seaborn.countplot(
    data=df,
    x='profile_gender',
    color='steelblue'
)
plt.show()
print(df.profile_gender) #columna
print(type(df.profile_gender)) #tipo de datos, es útil imprimir y entender el tipo de datos, dimensiones, etc.
# Out:
# 0        Mujer
# 1       Hombre
# 2        Mujer
# 3       Hombre
# 4       Hombre
#          ...
# 6090    Hombre
# 6091    Hombre
# 6092    Hombre
# 6093    Hombre
# 6094    Hombre
# Name: profile_gender, Length: 6095, dtype: object
# <class 'pandas.core.series.Series'>

# %%
sorted_studies_levels = ['Primario', 'Secundario', 'Terciario', 'Universitario',
                         'Posgrado', 'Doctorado', 'Posdoctorado'] #lista de los nombres de categorías ordenadas
fig, axes = plt.subplots(ncols=2, figsize=(13,4)) #se genera la figura, se divide en dos lugares y se define su tamaño
#g = seaborn.countplot(df.profile_studies_level, color='steelblue', ax=axes[0]) #gráfico de conteos (en el lugar 0)
seaborn.countplot(
    data=df,
    x='profile_studies_level',
    color='steelblue',
    ax=axes[0]
)
axes[1].set_title('Studies Level (Ordered)')
#g = seaborn.countplot(df.profile_studies_level, color='steelblue', ax=axes[1],
#                  order=sorted_studies_levels)      #gráfico de conteos ordenado (en el lugar 1)
#for ax in axes:
 # ax.tick_params(labelrotation=30)  # en cada lugar (ax in axes) se rota la etiqueta

for ax in axes:
    ax.tick_params(axis='x', labelrotation=30)
    ax.set_xlabel('Education Level')
    ax.set_ylabel('Count')

plt.tight_layout()   # Better spacing
plt.show()

# Extra useful information
print("Value counts:")
print(df['profile_studies_level'].value_counts())
# Out:
# Value counts:
# profile_studies_level
# Universitario    4133
# Terciario        1135
# Secundario        449
# Posgrado          342
# Doctorado          30
# Posdoctorado        4
# Primario            2
# Name: count, dtype: int64

# %% [markdown]
# # Variables Numéricas

# %%
salary_col='salary_monthly_BRUTO' #defino variable con el nombre de la columna de interés
#salary_col='salary_monthly_NETO'

# %%
fig, axes = plt.subplots(nrows=2, figsize=(14, 10)) #se genera la figura, se divide en dos lugares y se define su tamaño

#seaborn.histplot(df[salary_col], bins=100, ax=axes[0], color='gray') #Histograma con 100 bins
#axes[0].axvline(df[salary_col].mean(), color='orangered',
#            linestyle='--', label='Media')
#axes[0].axvline(df[salary_col].median(), color='indigo',
#            linestyle='-.', label='Mediana')
# ==================== Full data ====================
seaborn.histplot(df[salary_col], bins=100, ax=axes[0], color='gray', kde=False)
axes[0].axvline(df[salary_col].mean(), color='orangered',
                linestyle='--', linewidth=2, label=f'Media: {df[salary_col].mean():,.0f}')
axes[0].axvline(df[salary_col].median(), color='indigo',
                linestyle='-.', linewidth=2, label=f'Mediana: {df[salary_col].median():,.0f}')

axes[0].set_title('Distribución Salarial - Todos los Datos')
axes[0].set_xlabel('Salario')
axes[0].set_ylabel('Frequencia')
axes[0].legend()

filtered_df = df[df[salary_col] < 200000] 
#seaborn.histplot(filtered_df[salary_col], bins=30, ax=axes[1], color='gray')
#axes[1].axvline(filtered_df[salary_col].mean(), color='orangery',
#            linestyle='--', label='Media')
#axes[1].axvline(filtered_df[salary_col].median(), color='indigo',
#            linestyle='-.', label='Mediana')
# ==================== Filtered data (< 200k) ====================
filtered_df = df[df[salary_col] < 200000]

seaborn.histplot(filtered_df[salary_col], bins=30, ax=axes[1], color='gray', kde=False)
axes[1].axvline(filtered_df[salary_col].mean(), color='orangered',
                linestyle='--', linewidth=2, label=f'Media: {filtered_df[salary_col].mean():,.0f}')
axes[1].axvline(filtered_df[salary_col].median(), color='indigo',
                linestyle='-.', linewidth=2, label=f'Mediana: {filtered_df[salary_col].median():,.0f}')

axes[1].set_title('Distribución Salarial - Filtrada (< 200,000)')
axes[1].set_xlabel('Salario')
axes[1].set_ylabel('Frequencia')
axes[1].legend()
seaborn.despine()           # Remove top and right spines
plt.tight_layout()
plt.show()
# Summary statistics
print("=== estadística Salarial ===")
print(df[salary_col].describe())
print(f"\nMediana: {df[salary_col].median():,.0f}")
print(f"Media:   {df[salary_col].mean():,.0f}")
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# === estadística Salarial ===
# count    6.095000e+03
# mean     1.240585e+05
# std      1.229124e+05
# min      1.000000e+00
# 25%      6.159500e+04
# 50%      9.600000e+04
# 75%      1.450000e+05
# max      2.180000e+06
# Name: salary_monthly_BRUTO, dtype: float64
#
# Mediana: 96,000
# Media:   124,059

# %%
print(df[salary_col][:4])
print(type(df[salary_col]))
# Out:
# 0     53000.0
# 1     79000.0
# 2    160000.0
# 3    130000.0
# Name: salary_monthly_BRUTO, dtype: float64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# #Varias Variables

# %% [markdown]
# ## Varias Categóricas

# %%
## Tabla de contingencia
pd.crosstab(df.profile_gender, df.profile_studies_level)#, normalize=True) #no están ordenados 
pd.crosstab(df.profile_gender, df.profile_studies_level)[sorted_studies_levels]#ordenados
# Out:
# profile_studies_level  Primario  Secundario  Terciario  Universitario  \
# profile_gender
# Hombre                        2         424        970           3447
# Mujer                         0          24        158            667
# Otros                         0           1          7             19
#
# profile_studies_level  Posgrado  Doctorado  Posdoctorado
# profile_gender
# Hombre                      256         19             4
# Mujer                        85          8             0
# Otros                         1          3             0

# %%
fig = plt.figure(figsize=(8,5))
exp = pd.crosstab(df.profile_gender,
                  df.profile_studies_level)[sorted_studies_levels]
seaborn.heatmap(exp, annot=True, fmt='g')
plt.xticks(rotation=30)
plt.yticks(rotation=0)
seaborn.despine()

# %%
## Tabla de contingencia normalizada, la suma de los valores da 1, son proporciones, estima probabilidad
pd.crosstab(df.profile_gender, df.profile_studies_level, normalize=True)[sorted_studies_levels]
# Out:
# profile_studies_level  Primario  Secundario  Terciario  Universitario  \
# profile_gender
# Hombre                 0.000328    0.069565   0.159147       0.565546
# Mujer                  0.000000    0.003938   0.025923       0.109434
# Otros                  0.000000    0.000164   0.001148       0.003117
#
# profile_studies_level  Posgrado  Doctorado  Posdoctorado
# profile_gender
# Hombre                 0.042002   0.003117      0.000656
# Mujer                  0.013946   0.001313      0.000000
# Otros                  0.000164   0.000492      0.000000

# %%
fig = plt.figure(figsize=(8,4))
seaborn.countplot(
    data=df,
    x='profile_studies_level',
    hue='profile_gender',
    order=sorted_studies_levels,
    palette='Set2'          # nice colors for gender
)
plt.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Primario'),
#   Text(1, 0, 'Secundario'),
#   Text(2, 0, 'Terciario'),
#   Text(3, 0, 'Universitario'),
#   Text(4, 0, 'Posgrado'),
#   Text(5, 0, 'Doctorado'),
#   Text(6, 0, 'Posdoctorado')])

# %% [markdown]
# ## Varias numéricas

# %%
max_age = 99
seaborn.pairplot(data=df[df.profile_age < max_age],
                 y_vars=['profile_age', 'salary_monthly_BRUTO'],
                 x_vars=['salary_monthly_NETO', 'salary_monthly_BRUTO'],
                 aspect=2, height=3)
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig = plt.figure(figsize=(8,4))
seaborn.jointplot(data=df[df.profile_age < max_age], x='salary_monthly_NETO',
                  y='profile_age', kind='hex', height=6) 
plt.axvline(df[df.profile_age < max_age]['salary_monthly_NETO'].mean(), color='orangered',
            linestyle='--', label='Media Salario')
plt.axhline(df[df.profile_age < max_age]['profile_age'].mean(), color='blue',
            linestyle='--', label='Media Edad')
plt.legend()
# Remove scietific notation
plt.ticklabel_format(style='plain', axis='y')
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Filter
df_filtered = df[df['profile_age'] < max_age].copy()

seaborn.kdeplot(
    data=df_filtered,
    x='salary_monthly_NETO',
    y='profile_age',
    fill=True,
    cmap='Blues',
    thresh=0.02,
    levels=20
)

seaborn.regplot(
    data=df_filtered,
    x='salary_monthly_NETO',
    y='profile_age',
    scatter=False,
    color='red',
    line_kws={'linestyle': '--'}
)

plt.title('Salary vs Age - KDE')
plt.xlabel('Monthly Net Salary')
plt.ylabel('Age')
seaborn.despine()
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 4
#       1 # Filter
#       2 df_filtered = df[df['profile_age'] < max_age].copy()
# ----> 4 seaborn.kdeplot(
#       5     data=df_filtered,
#       6     x='salary_monthly_NETO',
#       7     y='profile_age',
#       8     fill=True,
#       9     cmap='Blues',
#      10     thresh=0.02,
#      11     levels=20
#      12 )
#      14 seaborn.regplot(
#      15     data=df_filtered,
#      16     x='salary_monthly_NETO',
#    (...)
#      20     line_kws={'linestyle': '--'}
#      21 )
#      23 plt.title('Salary vs Age - KDE')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:1731, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1717     p.plot_univariate_density(
#    1718         multiple=multiple,
#    1719         common_norm=common_norm,
#    (...)
#    1726         **plot_kws,
#    1727     )
#    1729 else:
# -> 1731     p.plot_bivariate_density(
#    1732         common_norm=common_norm,
#    1733         fill=fill,
#    1734         levels=levels,
#    1735         thresh=thresh,
#    1736         legend=legend,
#    1737         color=color,
#    1738         warn_singular=warn_singular,
#    1739         cbar=cbar,
#    1740         cbar_ax=cbar_ax,
#    1741         cbar_kws=cbar_kws,
#    1742         estimate_kws=estimate_kws,
#    1743         **kwargs,
#    1744     )
#    1746 return ax
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:1192, in _DistributionPlotter.plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, warn_singular, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1185 cset = contour_func(
#    1186     xx, yy, density,
#    1187     levels=draw_levels[key],
#    1188     **contour_kws,
#    1189 )
#    1191 if "hue" not in self.variables:
# -> 1192     cset.collections[0].set_label(label)
#    1194 # Add a color bar representing the contour heights
#    1195 # Note: this shows iso densities, not iso proportions
#    1196 # See more notes in histplot about how this could be improved
#    1197 if cbar:
#
# AttributeError: 'QuadContourSet' object has no attribute 'collections'

# %%
max_age = 99
seaborn.pairplot(data=df[df.profile_age < max_age], y_vars=['salary_monthly_BRUTO'],
                 x_vars=['salary_monthly_NETO'],
                 aspect=2, height=4)

# %% [markdown]
# **Pregunta** ¿Cuáles le parece que son las ventajas de ver de a dos  (o más) variables simultáneamente?

# %% [markdown]
# ## Mixtas

# %%
filtered_df= df[df[salary_col] < 200000]
df_H= filtered_df[ filtered_df['profile_gender']=='Hombre']
df_M=filtered_df[ filtered_df['profile_gender']=='Mujer']

plt.hist(df_H[salary_col], color='orangered', bins=50)
plt.hist(df_M[salary_col], color='steelblue', bins=50) #aca importa el orden, cuidado con la superposición
plt.show()

# %%
seaborn.pairplot(data=df[df.profile_age < max_age], y_vars=['salary_monthly_NETO'],
                 x_vars=['salary_satisfaction'],
                 aspect=2, height=4)

# %% [markdown]
# Una desventaja de usar un pairplot para variables categóricas es la superposición de los puntos que tienen el mismo valor. Un gráfico que soluciona este problema es el `catplot`

# %%
seaborn.catplot(data=df[df.profile_age < max_age], y='salary_monthly_NETO',  #probar también con profile_age, 'profile_gender'
                x='salary_satisfaction', height=4, aspect=2)
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
seaborn.jointplot(data=df[df.profile_age < max_age], x='profile_age',
                  y='salary_monthly_NETO', hue='profile_gender',
                  kind='kde', height=8)
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# # Práctico para resolver en clase
#
# 1. Analice las variables `'salary_monthly_BRUTO'` (salario mensual Bruto) y `'salary_monthly_NETO'` (salario Neto) en conjunto, que comentarios puede hacer al respecto?

# %%
import numpy as np
max_age = 99
df_limpio=df[(df.profile_age < max_age) & (df.salary_monthly_BRUTO <950000)& (df.salary_monthly_NETO <950000)]
seaborn.pairplot(data=df_limpio, y_vars=['salary_monthly_BRUTO'],
                 x_vars=['salary_monthly_NETO'],
                 aspect=2, height=4)
plt.xticks(rotation=20)
# Out:
# (array([-200000.,       0.,  200000.,  400000.,  600000.,  800000.,
#         1000000.]),
#  [Text(-200000.0, 0, '−200000'),
#   Text(0.0, 0, '0'),
#   Text(200000.0, 0, '200000'),
#   Text(400000.0, 0, '400000'),
#   Text(600000.0, 0, '600000'),
#   Text(800000.0, 0, '800000'),
#   Text(1000000.0, 0, '1000000')])

# %% [markdown]
# 2. Generamos una nueva columna `'salary_monthly_DESCUENTOS'= 'salary_monthly_BRUTO'-'salary_monthly_NETO'`, es decir que contenga los descuentos mensuales.
# 3. Analice la distribución de esta columna de datos gráficamente.

# %%
df_limpio['salary_monthly_DESCUENTOS']=df_limpio.salary_monthly_BRUTO-df_limpio.salary_monthly_NETO #generamos una nueva columna
#print(df_limpio.loc[0:2,'salary_monthly_BRUTO']), print(df_limpio.loc[0:2,'salary_monthly_NETO'])
#print(df_limpio['salary_monthly_DESCUENTOS'][0:2]) 
df_limpio[0:3] #mire la última columna
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_14504\53396720.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['salary_monthly_DESCUENTOS']=df_limpio.salary_monthly_BRUTO-df_limpio.salary_monthly_NETO #generamos una nueva columna
#   profile_gender  profile_age work_country                    work_province  \
# 0          Mujer           26    Argentina  Ciudad Autónoma de Buenos Aires
# 1         Hombre           29    Argentina                       Corrientes
# 2          Mujer           22    Argentina  Ciudad Autónoma de Buenos Aires
#
#    profile_years_experience  work_years_in_company  \
# 0                       3.0                    3.0
# 1                       5.0                    2.0
# 2                       2.0                    0.0
#
#    work_years_in_current_position  work_people_in_charge_of  \
# 0                             3.0                         0
# 1                             2.0                         4
# 2                             0.0                         0
#
#   profile_studies_level profile_studies_level_state  ...  \
# 0         Universitario                    En curso  ...
# 1         Universitario                    En curso  ...
# 2            Secundario                  Completado  ...
#
#   profile_sexual_orientation profile_has_disabilities  \
# 0                 Homosexual                      NaN
# 1               Heterosexual                   Visual
# 2           Bisexual o queer                      NaN
#
#   profile_has_disabilities_hiring_difficulties company_employee_number  \
# 0                                          NaN                501-1000
# 1                                           No                 201-500
# 2                                           No               2001-5000
#
#                            company_main_activity company_recommended  \
# 0  Servicios / Consultoría de Software / Digital                   7
# 1                               Otras industrias                   8
# 2                               Otras industrias                   6
#
#   company_diversity_policies  \
# 0                          2
# 1                          9
# 2                          9
#
#                               company_extra_benefits  \
# 0  Capacitaciones y/o cursos, Comidas pagas / sub...
# 1  Horarios flexibles, Stock options / RSUs, Viát...
# 2  Clases de gimnasia online, Comidas pagas / sub...
#
#   company_best_companies_city salary_monthly_DESCUENTOS
# 0                         NaN                   10000.0
# 1                         NaN                   16000.0
# 2                         NaN                   33000.0
#
# [3 rows x 49 columns]

# %%
df_limpio['salary_monthly_DESCUENTOS'].mean()
# Out:
# 26106.769855948114

# %%
df_limpio.salary_monthly_BRUTO.mean()-df_limpio.salary_monthly_NETO.mean()
# Out:
# 26106.769855948107

# %% [markdown]
# Interpretemos correlación entre las columnas de sueldos

# %%
matcov=np.cov(df_limpio.salary_monthly_BRUTO,df_limpio.salary_monthly_NETO)
print('matriz de varianza covarianza:','\n',matcov,'\n')

corr=np.corrcoef(df_limpio.salary_monthly_BRUTO,df_limpio.salary_monthly_NETO)
print('matriz de correlaciones: \n ', corr,'\n')

print('correlación entra ambas variables: ',corr[0,1],'\n')

#df_limpio.salary_monthly_BRUTO.describe().apply(lambda s: '{0:.2f}'.format(s))
#df_limpio.salary_monthly_NETO.describe().apply(lambda s: '{0:.2f}'.format(s))
# Out:
# matriz de varianza covarianza:
#  [[9.46431011e+09 6.92546629e+09]
#  [6.92546629e+09 6.03396621e+09]]
#
# matriz de correlaciones:
#   [[1.         0.91643803]
#  [0.91643803 1.        ]]
#
# correlación entra ambas variables:  0.9164380272100755

# %% [markdown]
# **Copyright**
#
# The notebooks are provided as [Open Educational Resource](https://de.wikipedia.org/wiki/Open_Educational_Resources). Feel free to use the notebooks for your own educational purposes. The text is licensed under [Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/), the code of the IPython examples under the [MIT license](https://opensource.org/licenses/MIT).
